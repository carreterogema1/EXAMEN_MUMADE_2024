# %% [markdown]
# # GEMA CARRETERO RIVAS
# Problema 2

# %%
# %load_ext sql

# %%
# !pip install gdown==4.6.3
# !gdown 1Osmr7qVN0NMuqYxvLesNn7H4nqPCVbsU
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1Osmr7qVN0NMuqYxvLesNn7H4nqPCVbsU
# To: /content/data_berka.db
# 100% 70.2M/70.2M [00:00<00:00, 234MB/s]

# %%
# %sql sqlite:///data_berka.db

# %%
# %%sql
# SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';
# Out:
#  * sqlite:///data_berka.db
# Done.
# [('DISTRICT',),
#  ('ACCOUNT',),
#  ('TRANS',),
#  ('CLIENT',),
#  ('DISPOSITION',),
#  ('CREDIT_CARD',),
#  ('LOAN',),
#  ('PERMANENT_ORDER',)]

# %% [markdown]
# **Problema 2**
#
# Realizar un análisis de clustering sobre los distintos distritos de la República Checa basado en las siguientes características: A4, A5, A6, A9, A10, A11, A13, A14, A16 de los datos de la tabla district. Sería necesario indicar en cuántos grupos se dividiría y las características de cada uno de los grupos.

# %%
data_district = %sql SELECT * FROM DISTRICT
df_district = data_district.DataFrame()
# Out:
#  * sqlite:///data_berka.db
# Done.

# %%
df_district[["A4", "A5", "A6","A9", "A10", "A11", "A13", "A14", "A16" ]]
# Out:
#          A4  A5  A6  A9    A10    A11   A13  A14    A16
# 0   1204953   0   0   1  100.0  12541  0.43  167  99107
# 1     88884  80  26   5   46.7   8507  1.85  132   2674
# 2     75232  55  26   5   41.7   8980  2.21  111   2813
# 3    149893  63  29   6   67.4   9753  5.05  109   5892
# 4     95616  65  30   6   51.4   9307  4.43  118   3040
# ..      ...  ..  ..  ..    ...    ...   ...  ...    ...
# 72   182027  17  49   7   56.4   8746  3.74   90   4433
# 73   323870   0   0   1  100.0  10673  5.44  100  18347
# 74   138032  67  30   5   64.6   8819  5.66   99   4505
# 75   127369  31  32   7   51.2   8369  5.88  107   2807
# 76   148545   8  35   4   53.5   8909  5.56  113   3590
#
# [77 rows x 9 columns]

# %% [markdown]
# Aquí podemos observar las caracteristicas de cada grupo:

# %%
df_district[["A4", "A5", "A6","A9", "A10", "A11", "A13", "A14", "A16" ]]
df_district.describe()
# Out:
#               A1            A4          A5         A6         A7         A8  \
# count  77.000000  7.700000e+01   77.000000  77.000000  77.000000  77.000000
# mean   39.000000  1.338849e+05   48.623377  24.324675   6.272727   1.727273
# std    22.371857  1.369135e+05   32.741829  12.780991   4.015222   1.008338
# min     1.000000  4.282100e+04    0.000000   0.000000   0.000000   0.000000
# 25%    20.000000  8.585200e+04   22.000000  16.000000   4.000000   1.000000
# 50%    39.000000  1.088710e+05   49.000000  25.000000   6.000000   2.000000
# 75%    58.000000  1.390120e+05   71.000000  32.000000   8.000000   2.000000
# max    77.000000  1.204953e+06  151.000000  70.000000  20.000000   5.000000
#
#               A9         A10           A11        A13         A14  \
# count  77.000000   77.000000     77.000000  77.000000   77.000000
# mean    6.259740   63.035065   9031.675325   3.787013  116.129870
# std     2.435497   16.221727    790.202347   1.908480   16.608773
# ...

# %% [markdown]
# Lo dividiriamos en 3 grupos.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import random
